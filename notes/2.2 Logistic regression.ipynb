# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Set number of points in simulated dataset

# %%
n = 200

# %% [markdown]
# Generate data

# %%
np.random.seed(0)
X = np.vstack(
    (np.random.normal(-1., 1.0, (n//2, 2)), np.random.normal(1., 1.0, (n//2, 2)))
)
y = np.hstack((np.repeat(0,n//2), np.repeat(1,n//2)))

# %% [markdown]
# Plot data

# %%
plt.scatter(X[:,0],X[:,1],c=y)
#plt.savefig("logreg_data.pdf")

# %% [markdown]
# Perform logistic regression

# %%
from keras import models
from keras import layers
# Out:
# Using TensorFlow backend.

# %%
model = models.Sequential()
model.add(layers.Dense(1, input_dim=2, activation="sigmoid"))
# Out:
# WARNING:tensorflow:From /home/dennis/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer="adam", loss="binary_crossentropy",
    metrics=["accuracy"])

# %%
model.fit(X, y, epochs=500, validation_split=0.2)
# Out:
# WARNING:tensorflow:From /home/dennis/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 160 samples, validate on 40 samples
# Epoch 1/500
# 160/160 [==============================] - 0s 1ms/step - loss: 0.6466 - acc: 0.6125 - val_loss: 0.6513 - val_acc: 0.7000
# Epoch 2/500
# 160/160 [==============================] - 0s 61us/step - loss: 0.6423 - acc: 0.6188 - val_loss: 0.6496 - val_acc: 0.7000
# Epoch 3/500
# 160/160 [==============================] - 0s 96us/step - loss: 0.6379 - acc: 0.6312 - val_loss: 0.6477 - val_acc: 0.7000
# Epoch 4/500
# 160/160 [==============================] - 0s 88us/step - loss: 0.6334 - acc: 0.6375 - val_loss: 0.6459 - val_acc: 0.7000
# Epoch 5/500
# ...

# %% [markdown]
# Grid plot

# %%
grid_range = np.arange(-3., 3., 0.02)
dgrid = len(grid_range)
Xpred = np.array([(a, b) for a in grid_range for b in grid_range])
prob_pred = model.predict(Xpred)
ypred = np.round(prob_pred)
ypred = ypred.reshape((dgrid, dgrid))
ypred = np.flipud(ypred)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.imshow(ypred, extent=[-3,3,-3,3])
plt.savefig("classification_boundary.pdf")

# %%
prob_pred = model.predict(Xpred)
ppred = prob_pred.reshape((dgrid, dgrid))
ppred = np.flipud(ppred)
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.imshow(ppred, extent=[-3,3,-3,3])
plt.colorbar()
plt.savefig("classification_probability.pdf")
