# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import boston_housing
(x_train, y_train), (x_val, y_val) = boston_housing.load_data()

# %%
x_train[0:3,:]
# Out:
# array([[1.23247e+00, 0.00000e+00, 8.14000e+00, 0.00000e+00, 5.38000e-01,
#         6.14200e+00, 9.17000e+01, 3.97690e+00, 4.00000e+00, 3.07000e+02,
#         2.10000e+01, 3.96900e+02, 1.87200e+01],
#        [2.17700e-02, 8.25000e+01, 2.03000e+00, 0.00000e+00, 4.15000e-01,
#         7.61000e+00, 1.57000e+01, 6.27000e+00, 2.00000e+00, 3.48000e+02,
#         1.47000e+01, 3.95380e+02, 3.11000e+00],
#        [4.89822e+00, 0.00000e+00, 1.81000e+01, 0.00000e+00, 6.31000e-01,
#         4.97000e+00, 1.00000e+02, 1.33250e+00, 2.40000e+01, 6.66000e+02,
#         2.02000e+01, 3.75520e+02, 3.26000e+00]])

# %%
from keras import models
from keras import layers
model = models.Sequential()
model.add(layers.Dense(1, activation="linear", input_dim=13))
# Out:
# WARNING:tensorflow:From /home/dennis/.local/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
boston_hist = model.fit(x_train, y_train, epochs=5000,
    validation_data=(x_val, y_val))
# Out:
# WARNING:tensorflow:From /home/dennis/.local/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 404 samples, validate on 102 samples
# Epoch 1/5000
# 404/404 [==============================] - 0s 413us/step - loss: 19458.8572 - val_loss: 18736.9266
# Epoch 2/5000
# 404/404 [==============================] - 0s 65us/step - loss: 16442.3703 - val_loss: 15688.9616
# Epoch 3/5000
# 404/404 [==============================] - 0s 68us/step - loss: 13736.2383 - val_loss: 13047.8775
# Epoch 4/5000
# 404/404 [==============================] - 0s 47us/step - loss: 11416.6683 - val_loss: 10794.4827
# Epoch 5/5000
# 404/404 [==============================] - 0s 56us/step - loss: 9449.7901 - val_loss: 8890.9805
# Epoch 6/5000
# ...

# %%
import matplotlib.pyplot as plt
history_dict = boston_hist.history
train_loss = history_dict["loss"]
val_loss = history_dict["val_loss"]
epochs = range(1, len(train_loss) + 1)

# %%
plt.plot(epochs[100:], train_loss[100:], "b-", label="train")
plt.plot(epochs[100:], val_loss[100:], "r-", label="validation")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss");
#plt.savefig("boston_loss.pdf")

# %% [markdown]
# The validation loss is above the training loss at some points, which might suggest mild overfitting. This doesn't seem to cause any problems as the test loss does not begin to rise.

# %%
pred_train = model.predict(x_train)
pred_val = model.predict(x_val)

# %%
pred_train = model.predict(x_train)
pred_val = model.predict(x_val)
plt.plot(y_train, pred_train, "bo", label="train")
plt.plot(y_val, pred_val, "ro", label="validation")
plt.legend()
plt.xlabel("True value")
plt.ylabel("Prediction");
#plt.savefig("boston_pred.pdf")

# %% [markdown]
# The various outliers expain why the validation loss is sometimes higher, sometimes lower.
